# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
ab = pd.read_csv('habsos_20230714.csv')
# Out:
# C:\Users\Peter Doze\AppData\Local\Temp\ipykernel_38900\1205591160.py:1: DtypeWarning: Columns (18,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   ab = pd.read_csv('habsos_20230714.csv')

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205552 entries, 0 to 205551
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   STATE_ID         205552 non-null  object
#  1   DESCRIPTION      205531 non-null  object
#  2   LATITUDE         205552 non-null  float64
#  3   LONGITUDE        205552 non-null  float64
#  4   SAMPLE_DATE      205552 non-null  object
#  5   SAMPLE_DEPTH     200324 non-null  float64
#  6   GENUS            205552 non-null  object
#  7   SPECIES          205552 non-null  object
#  8   CATEGORY         204696 non-null  object
#  9   CELLCOUNT        205552 non-null  int64
#  10  CELLCOUNT_UNIT   205552 non-null  object
#  11  CELLCOUNT_QA     205552 non-null  int64
#  12  SALINITY         105763 non-null  float64
#  13  SALINITY_UNIT    105763 non-null  object
#  14  SALINITY_QA      205552 non-null  int64
#  15  WATER_TEMP       104163 non-null  float64
# ...

# %%
AB = ab.dropna()
AB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 102 to 157380
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATE_ID         82 non-null     object
#  1   DESCRIPTION      82 non-null     object
#  2   LATITUDE         82 non-null     float64
#  3   LONGITUDE        82 non-null     float64
#  4   SAMPLE_DATE      82 non-null     object
#  5   SAMPLE_DEPTH     82 non-null     float64
#  6   GENUS            82 non-null     object
#  7   SPECIES          82 non-null     object
#  8   CATEGORY         82 non-null     object
#  9   CELLCOUNT        82 non-null     int64
#  10  CELLCOUNT_UNIT   82 non-null     object
#  11  CELLCOUNT_QA     82 non-null     int64
#  12  SALINITY         82 non-null     float64
#  13  SALINITY_UNIT    82 non-null     object
#  14  SALINITY_QA      82 non-null     int64
#  15  WATER_TEMP       82 non-null     float64
# ...

# %%
AB
# Out:
#        STATE_ID                                     DESCRIPTION  LATITUDE  \
# 102          TX       West End Queen Isabella Memorial Causeway  26.07889
# 167          TX                West End Queen Isabella Causeway  26.07889
# 200          TX                West End Queen Isabella Causeway  26.07889
# 220          TX                West End Queen Isabella Causeway  26.07889
# 396          TX                West End Queen Isabella Causeway  26.07889
# ...         ...                                             ...       ...
# 127210       TX                   Boca Chica beach at Highway 4  26.01332
# 127258       TX                   Boca Chica beach at Highway 4  26.01332
# 128411       TX                   Bahia Grande Southwest Corner  26.01221
# 128412       TX                   Bahia Grande Southwest Corner  26.01221
# 157380       TX  1 mi. S Matagorda Ship Channel Jetty Matagorda  28.41473
#
#         LONGITUDE       SAMPLE_DATE  SAMPLE_DEPTH    GENUS SPECIES  \
# ...

# %%
ab.iloc[101]
# Out:
# STATE_ID                         FL
# DESCRIPTION        Lido Beach; W of
# LATITUDE                   27.31002
# LONGITUDE                 -82.57707
# SAMPLE_DATE         1/28/2016 14:00
# SAMPLE_DEPTH                    0.5
# GENUS                       Karenia
# SPECIES                      brevis
# CATEGORY                       high
# CELLCOUNT                  35267000
# CELLCOUNT_UNIT              cells/L
# CELLCOUNT_QA                      1
# SALINITY                        NaN
# SALINITY_UNIT                   NaN
# SALINITY_QA                       9
# WATER_TEMP                      NaN
# WATER_TEMP_UNIT                 NaN
# WATER_TEMP_QA                   9.0
# WIND_DIR                        NaN
# WIND_DIR_UNIT                   NaN
# WIND_DIR_QA                     9.0
# WIND_SPEED                      NaN
# WIND_SPEED_UNIT                 NaN
# WIND_SPEED_QA                   9.0
# Name: 101, dtype: object

# %% [markdown]
# # Lost a lot of rows by dropping the nans might want to just look for and drop the nans that we think will be vital eg. water temperature

# %%
AB['STATE_ID'].unique()
# Out:
# array(['TX'], dtype=object)

# %% [markdown]
# ## Texas is the only state with no nans might want to just focus on this state to make things easier and deal with the nans in Texas

# %%
AB['DESCRIPTION'].unique()
# Out:
# array(['West End Queen Isabella Memorial Causeway',
#        'West End Queen Isabella Causeway',
#        'West End of Queen Isabella Causeway',
#        'UTPA Coastal Studies Laboratory', 'UTPA Coastal Studies Lab',
#        'South Padre Marina boat ramp',
#        'South Padre Island Beach Access 6',
#        'South Padre Island Beach Access 5', 'San Martin Boat Ramp',
#        'PINS Northern Park Boundary (North Beach)',
#        'PINS Bird Island Basin', 'PINS 15 mile marker',
#        'PINS 0 mile marker', 'Pass Cavallo 1 mi. offshore',
#        'Mesquite Bay @ Cedar Bayou',
#        'Mat. Ship Channel South Jetty (end)', 'Mat R5',
#        'Isla Blanca boat ramp', 'Inside Pass Cavallo',
#        'ICCW @ CC Ship Channel', 'Holly Beach',
#        'east end Queen Isabella Causeway',
#        'Corpus Christi Bay, Shamrock Cove',
#        'Corpus Christi Bay near Portland shore',
#        'Corpus Christi Bay near Point Mustang',
#        'Corpus Christi Bay near Oso Bay',
# ...

# %%
len(AB['DESCRIPTION'].unique())
# Out:
# 37

# %% [markdown]
# ## 37 locations within Texas we can try making a model based on all the data together and the data individually?

# %%
AB[AB['DESCRIPTION']=='Corpus Christi Bay near Point Mustang']
# Out:
#       STATE_ID                            DESCRIPTION  LATITUDE  LONGITUDE  \
# 35724       TX  Corpus Christi Bay near Point Mustang  27.82361  -97.13944
# 35867       TX  Corpus Christi Bay near Point Mustang  27.82389  -97.13861
#
#             SAMPLE_DATE  SAMPLE_DEPTH    GENUS SPECIES  CATEGORY  CELLCOUNT  \
# 35724  10/18/2006 15:05           0.0  Karenia  brevis    medium     198000
# 35867   11/7/2006 19:14           0.0  Karenia  brevis  very low       2200
#
#        ... SALINITY_QA  WATER_TEMP  WATER_TEMP_UNIT WATER_TEMP_QA  WIND_DIR  \
# 35724  ...           1   27.800000           deg. C           1.0     180.0
# 35867  ...           1   23.777778           deg. C           5.0     180.0
#
#        WIND_DIR_UNIT WIND_DIR_QA  WIND_SPEED WIND_SPEED_UNIT WIND_SPEED_QA
# 35724            deg         5.0         6.0             mph           1.0
# 35867            deg         5.0        12.0             mph           1.0
#
# [2 rows x 24 columns]

# %%
AB[AB['DESCRIPTION']=='Corpus Christi Bay near Nueces Bay']
# Out:
#       STATE_ID                         DESCRIPTION  LATITUDE  LONGITUDE  \
# 35870       TX  Corpus Christi Bay near Nueces Bay  27.83833  -97.37528
#
#             SAMPLE_DATE  SAMPLE_DEPTH    GENUS SPECIES CATEGORY  CELLCOUNT  \
# 35870  10/18/2006 13:58           0.0  Karenia  brevis      low      68800
#
#        ... SALINITY_QA  WATER_TEMP  WATER_TEMP_UNIT WATER_TEMP_QA  WIND_DIR  \
# 35870  ...           1        27.7           deg. C           1.0     180.0
#
#        WIND_DIR_UNIT WIND_DIR_QA  WIND_SPEED WIND_SPEED_UNIT WIND_SPEED_QA
# 35870            deg         5.0         6.0             mph           1.0
#
# [1 rows x 24 columns]

# %%
AB.groupby('DESCRIPTION').count()
# Out:
#                                                 STATE_ID  LATITUDE  LONGITUDE  \
# DESCRIPTION
# 1 mi. S Matagorda Ship Channel Jetty Matagorda         1         1          1
# Bahia Grande Southwest Corner                          2         2          2
# Boca Chica Beach, 1.1 mi. north of Hwy 4               1         1          1
# Boca Chica Beach, 4.5 mi. north of Hwy 4               1         1          1
# Boca Chica beach at Highway 4                          2         2          2
# Brazos-Santiago Pass                                   5         5          5
# Canal C at Long Island Village                         1         1          1
# Clayton''s Beach Bar                                   2         2          2
# Corpus Christi Bay (near COR 22)                       2         2          2
# Corpus Christi Bay near Cole Park                      2         2          2
# Corpus Christi Bay near Nueces Bay                     1         1          1
# ...

# %%
ab['STATE_ID'].unique()
# Out:
# array(['FL', 'TX', 'AL', 'MS'], dtype=object)
